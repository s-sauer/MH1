# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preditor-prey model (a.k.a. Lotka-Volterra model)
#
# https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations
#
# \begin{align}
#  \frac{dx}{dt} &= + a \ x - b \ x \cdot y, \\
#  \frac{dy}{dt} &= - c \ y + d \ x \cdot y ,
# \end{align}
#
# * $x$ ... prey (e.g., rabbits)
# * $y$ ... preditor (e.g., foxes)

# %%
# parameter values and inital values
a = 2 # reproduction rate of rabbits, unit: 1/year
b = 0.01 # rabbit reduction rate, unit: 1/(fox*year)
c = 3 # fox reduction rate, unit: 1/year
d = 0.01 # fox reproduction rate, unit: 1/(rabbit*year)
rabbits_init = 100 #
foxes_init = 2 #
T_max = 10 # max. simulation time in years

# %%
# define system of ordinary differential equations (ODE)
def rhs(t, y):
    [rabbits, foxes] = y
    dRdt = +a*rabbits - b*foxes*rabbits
    dFdt = -c*foxes + d*foxes*rabbits
    return [dRdt, dFdt]

# %%
solution = solve_ivp(rhs, [0,T_max], [rabbits_init, foxes_init], t_eval=np.linspace(0,T_max,1001))

# %%
plt.plot(solution.t, solution.y.T)
plt.legend(['rabbits','foxes'])
plt.xlabel('Time [years]')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')
